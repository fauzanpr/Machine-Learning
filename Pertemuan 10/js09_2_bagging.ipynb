# %% [markdown]
# ## Identitas
# Nama : Fauzan Pradana
# <br />
# Kelas : 3G
# <br />
# NIM : 2041720224
# <br />
# Absen : 10

# %% [markdown]
# ## Bagging dengan RandomForest
#
# Pada kasus ini kita akan menggunakan salah satu metode bagging yaitu RandomForest untuk mengklasifikasikan jenis tumor. Dalam latihan ini Anda akan melakukan training dengan data [Wisconsin Breast Cancer Dataset](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data) dari UCI machine learning repository. Latihan ini akan melakukan prediksi memprediksi apakah tumor ganas atau jinak.
#
# Kita akan membandingkan performa dari algoritma Decision Tree dan RandomForest pada kasus ini.

# %% [markdown]
# ### Import Library

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # import DT
from sklearn.ensemble import RandomForestClassifier # import RandomForest
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ### Persiapan Data

# %%
# Load data
df = pd.read_csv('data/wbc.csv')

df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Cek kolom null
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
set(df['diagnosis'])
# Out:
# {'B', 'M'}

# %%
# Seleksi fitur

# Slice dataframe mulai dari kolom 'radius_mean' sampai 'fractal_dimension_worst'
X = df.iloc[:,2:-1]
y = df['diagnosis']
y = y.map({'M':1, 'B':0}) # Encode label

# Cek jumlah fitur dan instance
X.shape
# Out:
# (569, 30)

# %% [markdown]
# ### Split data training dan testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### Traning Decision Tree

# %%
# Secara default, DecisionTreeClassifier dari scikit-learn akan menggunakan nilai "Gini" untuk kriteria
# Terdapat beberapa "hyperparamater" yang dapat digunakan. Silahka baca dokumentasi
# Pada kasus ini kita akan menggunakan parameter default
dt = DecisionTreeClassifier()

# Sesuaikan dt ke set training
dt.fit(X_train, y_train)

# Memprediksi label set test
y_pred_dt = dt.predict(X_test)

#  menghitung set accuracy
acc_dt = accuracy_score(y_test, y_pred_dt)
print("Test set accuracy: {:.2f}".format(acc_dt))
print(f"Test set accuracy: {acc_dt}")
# Out:
# Test set accuracy: 0.94
# Test set accuracy: 0.9385964912280702

# %% [markdown]
# ### Training RandomForest

# %%
# Pada kasus kali ini kita akan menggunakan estimator pada RandomForest
# Untuk detail parameter (hyperparameter) silahkan cek dokumentasi

rf = RandomForestClassifier(n_estimators=10, random_state=1)

# Sesuaikan dt ke set training
rf.fit(X_train, y_train)

# Memprediksi label set test
y_pred_rf = rf.predict(X_test)

#  menghitung set accuracy
acc_rf = accuracy_score(y_test, y_pred_rf)
print("Test set accuracy: {:.2f}".format(acc_rf))
print(f"Test set accuracy: {acc_rf}")
# Out:
# Test set accuracy: 0.96
# Test set accuracy: 0.956140350877193

# %% [markdown]
# ### Tugas
#
# Pada folder data, terdapat dataset jamur yang kita gunakan pada materi Decision Tree. Berdasarkan dataset yang sama, bandingkan peforma antara algoritma DT dan RandomForest. Gunakan tunning hyperparameter untuk mendapatkan parameter dan akurasi yang terbaik.

# %%
df_mushroom = pd.read_csv('data/mushrooms.csv')

# %% [markdown]
# ## Pengenalan Data
# Tahap ini saya melakukan beberapa pengecekan terhadap isi data pada mushroom.csv

# %%
df_mushroom.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df_mushroom.tail()
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
#Melihat info detail dari data
df_mushroom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
#Cek apakah ada data yang kosong
df_mushroom.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
print(f'data ini memiliki {df_mushroom.shape[0]} baris')
print(f'data ini memiliki {df_mushroom.shape[1]} kolom')
# Out:
# data ini memiliki 8124 baris
# data ini memiliki 23 kolom

# %%
set(df_mushroom['class'])
# Out:
# {'e', 'p'}

# %%
test = df_mushroom.iloc[:, 1:-1]
test
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            x           s         n       t    p               f
# 1            x           s         y       t    a               f
# 2            b           s         w       t    l               f
# 3            x           y         w       t    p               f
# 4            x           s         g       f    n               f
# ...        ...         ...       ...     ...  ...             ...
# 8119         k           s         n       f    n               a
# 8120         x           s         n       f    n               a
# 8121         f           s         n       f    n               a
# 8122         k           y         n       f    y               f
# 8123         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# 1               c         b          k           e  ...
# ...

# %% [markdown]
# ## Persiapan Data
# persiapan dilakukan dengan menyesuaikan format data dengan inputan library yang digunakan, dilakukan dengan melakukan encoding sehingga akan menjadi integer. Selain itu, dilakukan pemisahan antara data training dan testing serta menentukan X dan y nya.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Inisiasi label encoder
encode = LabelEncoder()

# Terpakan label encoder
df_mushroom['cap-shape'] = encode.fit_transform(df_mushroom['cap-shape'])
df_mushroom['cap-surface'] = encode.fit_transform(df_mushroom['cap-surface'])
df_mushroom['cap-color'] = encode.fit_transform(df_mushroom['cap-color'])
df_mushroom['bruises'] = encode.fit_transform(df_mushroom['bruises'])
df_mushroom['odor'] = encode.fit_transform(df_mushroom['odor'])
df_mushroom['gill-attachment'] = encode.fit_transform(df_mushroom['gill-attachment'])
df_mushroom['gill-spacing'] = encode.fit_transform(df_mushroom['gill-spacing'])
df_mushroom['gill-size'] = encode.fit_transform(df_mushroom['gill-size'])
df_mushroom['gill-color'] = encode.fit_transform(df_mushroom['gill-color'])
df_mushroom['stalk-shape'] = encode.fit_transform(df_mushroom['stalk-shape'])
df_mushroom['stalk-root'] = encode.fit_transform(df_mushroom['stalk-root'])
df_mushroom['stalk-surface-above-ring'] = encode.fit_transform(df_mushroom['stalk-surface-above-ring'])
df_mushroom['stalk-surface-below-ring'] = encode.fit_transform(df_mushroom['stalk-surface-below-ring'])
df_mushroom['stalk-color-above-ring'] = encode.fit_transform(df_mushroom['stalk-color-above-ring'])
df_mushroom['stalk-color-below-ring'] = encode.fit_transform(df_mushroom['stalk-color-below-ring'])
df_mushroom['veil-type'] = encode.fit_transform(df_mushroom['veil-type'])
df_mushroom['veil-color'] = encode.fit_transform(df_mushroom['veil-color'])
df_mushroom['ring-number'] = encode.fit_transform(df_mushroom['ring-number'])
df_mushroom['ring-type'] = encode.fit_transform(df_mushroom['ring-type'])
df_mushroom['spore-print-color'] = encode.fit_transform(df_mushroom['spore-print-color'])
df_mushroom['population'] = encode.fit_transform(df_mushroom['population'])
df_mushroom['habitat'] = encode.fit_transform(df_mushroom['habitat'])

# %%
# Seleksi fitur

# Slice dataframe
X = df_mushroom.iloc[:, 1:-1]
y = df_mushroom['class']
y = y.map({'e':1, 'p':0}) # Encode label

# Cek jumlah fitur dan instance
X.shape
# Out:
# (8124, 21)

# %%
df_mushroom
# Out:
#      class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0        p          5            2          4        1     6                1
# 1        e          5            2          9        1     0                1
# 2        e          0            2          8        1     3                1
# 3        p          5            3          8        1     6                1
# 4        e          5            2          3        0     5                1
# ...    ...        ...          ...        ...      ...   ...              ...
# 8119     e          3            2          4        0     5                0
# 8120     e          5            2          4        0     5                0
# 8121     e          2            2          4        0     5                0
# 8122     p          3            3          4        0     8                1
# 8123     e          5            2          4        0     5                0
#
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 1610          5            0          4        0     5                1
# 1939          5            2          3        0     5                1
# 5573          5            3          2        0     8                1
# 7076          5            2          2        0     8                1
# 2000          5            0          4        1     5                1
# ...         ...          ...        ...      ...   ...              ...
# 7935          3            3          2        0     8                1
# 5192          5            3          4        0     7                1
# 3980          2            3          3        0     2                1
# 235           5            0          8        1     3                1
# 5157          5            2          0        1     2                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
# Secara default, DecisionTreeClassifier dari scikit-learn akan menggunakan nilai "Gini" untuk kriteria
# Terdapat beberapa "hyperparamater" yang dapat digunakan. Silahka baca dokumentasi
# Pada kasus ini kita akan menggunakan parameter default
dt_mushroom = DecisionTreeClassifier()

# Sesuaikan dt ke set training
dt_mushroom.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Memprediksi label set test
y_pred_dt_mushroom = dt_mushroom.predict(X_test)

#  menghitung set accuracy
acc_dt_mushroom = accuracy_score(y_test, y_pred_dt_mushroom)
print("Test set accuracy: {:.2f}".format(acc_dt_mushroom))
print(f"Test set accuracy: {acc_dt_mushroom}")
# Out:
# Test set accuracy: 1.00
# Test set accuracy: 1.0

# %%
# Pada kasus kali ini kita akan menggunakan estimator pada RandomForest
# Untuk detail parameter (hyperparameter) silahkan cek dokumentasi

rf_mushroom = RandomForestClassifier(n_estimators=100, random_state=1)

# Sesuaikan dt ke set training
rf_mushroom.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
# Memprediksi label set test
y_pred_rf_mushroom = rf_mushroom.predict(X_test)

#  menghitung set accuracy
acc_rf_mushroom = accuracy_score(y_test, y_pred_rf_mushroom)
print("Test set accuracy: {:.2f}".format(acc_rf_mushroom))
print(f"Test set accuracy: {acc_rf_mushroom}")
# Out:
# Test set accuracy: 1.00
# Test set accuracy: 1.0

# %% [markdown]
# ## Kesimpulan

# %% [markdown]
# Pada metode ini, hasil akurasi yang dihasilkan sangat baik, yaitu sebesar 1.0
